# %%
# Prematurity Risk Detection Using AI
# -------------------------------------
# This script uses Python's machine learning libraries for analyzing and predicting the risk of prematurity in neonates.

# Step 1: Import Necessary Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Step 2: Load and Explore Dataset
# Replace 'dataset.csv' with the path to your dataset.
data = pd.read_csv('/Maternal Health Risk Data Set1.csv')
print("Dataset loaded successfully!")

# Display the first few rows
data.head()

 Step 3: Data Preprocessing
# Handle missing values
# data.fillna(method='ffill', inplace=True)
data.ffill(inplace=True)

# Encode categorical data (if applicable)
data = pd.get_dummies(data, drop_first=True)

# Separate features and target
X = data.drop('prematurity_risk', axis=1)  # Replace 'prematurity_risk' with the actual target column
Y = data['prematurity_risk']

# Train-test split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Step 4: Feature Scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Step 5: Train the Model
model = RandomForestClassifier(random_state=42)
model.fit(X_train, Y_train)

# Step 6: Evaluate the Model
Y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(Y_test, Y_pred))
print("Confusion Matrix:\n", confusion_matrix(Y_test, Y_pred))
print("Classification Report:\n", classification_report(Y_test, Y_pred))

# Step 7: Feature Importance Analysis
importance = model.feature_importances_
feature_names = X.columns

plt.figure(figsize=(10, 8))
sns.barplot(x=importance, y=feature_names)
plt.title('Feature Importance')
plt.show()

# Step 8: Save the Model for Future Use
import joblib
joblib.dump(model, 'prematurity_risk_model.pkl')
print("Model saved successfully!")
# Out:
# Dataset loaded successfully!
# <ipython-input-1-22ee4031457c>:25: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-22ee4031457c> in <cell line: 0>()
#      29
#      30 # Separate features and target
# ---> 31 X = data.drop('prematurity_risk', axis=1)  # Replace 'prematurity_risk' with the actual target column
#      32 Y = data['prematurity_risk']
#      33
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# ...

# %%
# Prematurity Risk Detection Using AI
# -------------------------------------
# This script uses Python's machine learning libraries for analyzing and predicting the risk of prematurity in neonates.

# Step 1: Import Necessary Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Step 2: Load and Explore Dataset
# Replace 'dataset.csv' with the path to your dataset.
data = pd.read_csv('/content/Maternal Health Risk Data Set1.csv')
print("Dataset loaded successfully!")

# Display the first few rows
data.head()
# Out:
# Dataset loaded successfully!
#    Age  SystolicBP  DiastolicBP  Blood sugar  BodyTemp  HeartRate  RiskLevel
# 0   25         130           80         15.0      98.0         86  high risk
# 1   35         140           90         13.0      98.0         70  high risk
# 2   29          90           70          8.0     100.0         80  high risk
# 3   30         140           85          7.0      98.0         70  high risk
# 4   35         120           60          6.1      98.0         76   low risk

# %%
#Step 3: Data Preprocessing
# Handle missing values
# data.fillna(method='ffill', inplace=True)
data.ffill(inplace=True)
data.head()
# Out:
#    Age  SystolicBP  DiastolicBP  Blood sugar  BodyTemp  HeartRate  RiskLevel
# 0   25         130           80         15.0      98.0         86  high risk
# 1   35         140           90         13.0      98.0         70  high risk
# 2   29          90           70          8.0     100.0         80  high risk
# 3   30         140           85          7.0      98.0         70  high risk
# 4   35         120           60          6.1      98.0         76   low risk

# %%
data = pd.get_dummies(data, drop_first=True)
X = data.drop('RiskLevel_low risk', axis=1)
Y = data['RiskLevel_low risk']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
data.head()
# Out:
#    Age  SystolicBP  DiastolicBP  Blood sugar  BodyTemp  HeartRate  \
# 0   25         130           80         15.0      98.0         86
# 1   35         140           90         13.0      98.0         70
# 2   29          90           70          8.0     100.0         80
# 3   30         140           85          7.0      98.0         70
# 4   35         120           60          6.1      98.0         76
#
#    RiskLevel_low risk  RiskLevel_mid risk
# 0               False               False
# 1               False               False
# 2               False               False
# 3               False               False
# 4                True               False

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
data.head()
# Out:
#    Age  SystolicBP  DiastolicBP  Blood sugar  BodyTemp  HeartRate  \
# 0   25         130           80         15.0      98.0         86
# 1   35         140           90         13.0      98.0         70
# 2   29          90           70          8.0     100.0         80
# 3   30         140           85          7.0      98.0         70
# 4   35         120           60          6.1      98.0         76
#
#    RiskLevel_low risk  RiskLevel_mid risk
# 0               False               False
# 1               False               False
# 2               False               False
# 3               False               False
# 4                True               False

# %%
model = RandomForestClassifier(random_state=42)
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
Y_pred = model.predict(X_test)
data.head()
# Out:
#    Age  SystolicBP  DiastolicBP  Blood sugar  BodyTemp  HeartRate  \
# 0   25         130           80         15.0      98.0         86
# 1   35         140           90         13.0      98.0         70
# 2   29          90           70          8.0     100.0         80
# 3   30         140           85          7.0      98.0         70
# 4   35         120           60          6.1      98.0         76
#
#    RiskLevel_low risk  RiskLevel_mid risk
# 0               False               False
# 1               False               False
# 2               False               False
# 3               False               False
# 4                True               False

# %%
print("Accuracy:", accuracy_score(Y_test, Y_pred))
print("Confusion Matrix:\n", confusion_matrix(Y_test, Y_pred))
print("Classification Report:\n", classification_report(Y_test, Y_pred))
# Out:
# Accuracy: 0.9704433497536946
# Confusion Matrix:
#  [[121   2]
#  [  4  76]]
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.97      0.98      0.98       123
#         True       0.97      0.95      0.96        80
#
#     accuracy                           0.97       203
#    macro avg       0.97      0.97      0.97       203
# weighted avg       0.97      0.97      0.97       203

# %%
# Step 7: Feature Importance Analysis
importance = model.feature_importances_
feature_names = X.columns
data.head()
# Out:
#    Age  SystolicBP  DiastolicBP  Blood sugar  BodyTemp  HeartRate  \
# 0   25         130           80         15.0      98.0         86
# 1   35         140           90         13.0      98.0         70
# 2   29          90           70          8.0     100.0         80
# 3   30         140           85          7.0      98.0         70
# 4   35         120           60          6.1      98.0         76
#
#    RiskLevel_low risk  RiskLevel_mid risk
# 0               False               False
# 1               False               False
# 2               False               False
# 3               False               False
# 4                True               False

# %%
plt.figure(figsize=(10, 8))
sns.barplot(x=importance, y=feature_names)
plt.title('Feature Importance')
plt.show()

# %%
# Step 8: Save the Model for Future Use
import joblib
joblib.dump(model, 'prematurity_risk_model.pkl')
print("Model saved successfully!")
# Out:
# Model saved successfully!
